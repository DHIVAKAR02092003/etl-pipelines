# %%
#Loading a Data
import pandas as pd 
customer_data = pd.read_csv(r"C:\Users\Dhivakar\pipelines\us_customer_data 1.csv")
customer_data
# Out:
#      customer_id              name                        email         phone  \
# 0              1     Michelle Kidd           vayala@example.net  619-723-4258
# 1              2       Brad Newton  taylorcatherine@example.net  537-674-1158
# 2              3      Larry Torres         dsanchez@example.net  810-256-4505
# 3              4    Kimberly Price    jessicaknight@example.com  423-222-9779
# 4              5  Matthew Phillips        qwilliams@example.com  220-763-3522
# ..           ...               ...                          ...           ...
# 995          996    Jerry Mcdaniel       walkerlisa@example.net  638-989-9441
# 996          997      Jodi Simpson           eric24@example.org  483-625-2940
# 997          998     Crystal Brown         pshaffer@example.net  390-747-3088
# 998          999    Gregory Duarte    caitlindunlap@example.org  257-409-8196
# 999         1000       Jason Walls        michael42@example.com  692-333-6880
#
# ...

# %%
#transform
customer_data['name'] = customer_data['name'].str.strip().str.title()
customer_data['email'] = customer_data['email'].str.strip().str.lower()
#digits only
customer_data['phone'] = customer_data['phone'].astype(str).str.replace(r'\D', '', regex = True)

# %%
#extracting codes
customer_data['country_code'] = customer_data['address'].str.slice(-8,-6)
customer_data.head()
# Out:
#    customer_id              name                        email       phone  \
# 0            1     Michelle Kidd           vayala@example.net  6197234258
# 1            2       Brad Newton  taylorcatherine@example.net  5376741158
# 2            3      Larry Torres         dsanchez@example.net  8102564505
# 3            4    Kimberly Price    jessicaknight@example.com  4232229779
# 4            5  Matthew Phillips        qwilliams@example.com  2207633522
#
#                                              address registration_date  \
# 0                        USNS Santiago, FPO AE 80872        25-01-2025
# 1  38783 Oliver Street, West Kristenborough, MT 9...        13-07-2023
# 2     6845 Steele Turnpike, West Erikabury, UT 37487        18-08-2023
# 3         1631 Alexis Meadows, Lake Amanda, CA 75179        08-12-2024
# 4  2274 Williams Heights Suite 895, Andersonhaven...        03-02-2024
#
#   loyalty_status country_code
# 0           Gold           AE
# 1         Silver           MT
# ...

# %%
customer_data[customer_data['customer_id'] == 400]
# Out:
#      customer_id              name                email phone  \
# 399          400  Alejandro Romero  david51@example.com
#
#                                               address registration_date  \
# 399  303 Garcia Extension, Lake Rebeccaberg, MO 28901        12-10-2024
#
#     loyalty_status country_code
# 399         Bronze           MO

# %%
def format_phone(row):
    phone = str(row['phone']).strip()
    
    phone_digits = ''.join(filter(str.isdigit, phone))

    if len(phone_digits) != 10:
        return 'Invalid'

    code = row['country_code']
    if code == 'IN':
        return '+91 ' + phone_digits
    elif code == 'AE':
        return '+971 ' + phone_digits
    elif code == 'FM':
        return '+691 ' + phone_digits
    elif code == 'PW':
        return '+680 ' + phone_digits
    else:
        return '+1 ' + phone_digits


customer_data['phone'] = customer_data.apply(format_phone, axis=1)

# %%
customer_data.head()
# Out:
#    customer_id              name                        email  \
# 0            1     Michelle Kidd           vayala@example.net
# 1            2       Brad Newton  taylorcatherine@example.net
# 2            3      Larry Torres         dsanchez@example.net
# 3            4    Kimberly Price    jessicaknight@example.com
# 4            5  Matthew Phillips        qwilliams@example.com
#
#              phone                                            address  \
# 0  +971 6197234258                        USNS Santiago, FPO AE 80872
# 1    +1 5376741158  38783 Oliver Street, West Kristenborough, MT 9...
# 2    +1 8102564505     6845 Steele Turnpike, West Erikabury, UT 37487
# 3    +1 4232229779         1631 Alexis Meadows, Lake Amanda, CA 75179
# 4    +1 2207633522  2274 Williams Heights Suite 895, Andersonhaven...
#
#   registration_date loyalty_status country_code
# 0        25-01-2025           Gold           AE
# 1        13-07-2023         Silver           MT
# ...

# %%
customer_data.loc[100]
# Out:
# customer_id                                                101
# name                                                Amy Graham
# email                                 nicolehorton@example.net
# phone                                            +1 2291386421
# address              236 Robert Mall, Stephaniemouth, ME 67219
# registration_date                                   25-02-2024
# loyalty_status                                          Bronze
# country_code                                                ME
# Name: 100, dtype: object

# %%
customer_data[customer_data['customer_id']==100]
# Out:
#     customer_id         name               email          phone  \
# 99          100  Aaron Irwin  wdavis@example.org  +1 6788162094
#
#                                              address registration_date  \
# 99  4938 Natalie Coves Suite 528, Cookfurt, DC 27968        15-06-2024
#
#    loyalty_status country_code
# 99         Bronze           DC

# %%
customer_data.to_csv('cleaned_customer_data2.csv', index=False)
print("Data Cleaned, Mapped with codes and loaded successfully")
# Out:
# Data Cleaned, Mapped with codes and loaded successfully
